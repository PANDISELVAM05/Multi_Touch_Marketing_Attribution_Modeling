# %% [markdown]
# ### Statistical_Analysis1

# %%
#BASIC STATISTICS AND NORMALIZATION SCRIPT
import pandas as pd
import numpy as np
import sys

# Redirect output to both console and file for Part 2
class DualOutput:
    def __init__(self, filename):
        self.terminal = sys.stdout
        self.log = open(filename, "w", encoding="utf-8")
    def write(self, message):
        self.terminal.write(message)
        self.log.write(message)
    def flush(self):
        self.terminal.flush()
        self.log.flush()

sys.stdout = DualOutput("channel_cost2.txt")

# Load cleaned data from Part 1
cleaned_file_path = r"D:\PROJECT\Project2\DataCleaning\channel_cost.csv"
df_cleaned = pd.read_csv(cleaned_file_path)

# =======================================
# Step 1: Basic Statistics
# =======================================
print("\nBasic Statistics of Cleaned Data:")
print(df_cleaned.describe())
# ===============================================================
# Step 2: Calculate Basic Statistics for Numerical Columns
# Based on cleaned data & display all column values
# ===============================================================
numerical_cols = df_cleaned.select_dtypes(include=[np.number]).columns.tolist()


print("\n\n\nBasic Statistics (Cleaned Data):")
for col in numerical_cols:
    mean_val = np.mean(df_cleaned[col])
    median_val = np.median(df_cleaned[col])
    mode_val = df_cleaned[col].mode()[0] if not df_cleaned[col].mode().empty else np.nan
    
    print(f"\nColumn: {col}")
    print(f"Mean: {mean_val}")
    print(f"Median: {median_val}")
    print(f"Mode: {mode_val}")

# ===============================================================
# Step 3: Normalize Numerical Features using Min-Max Scaling
# Based on cleaned data & display all column values
# ===============================================================
print("\n\n\nNormalized Numerical Features (Cleaned Data):")
normalized_df = df_cleaned.copy()

for col in numerical_cols:
    min_val = df_cleaned[col].min()
    max_val = df_cleaned[col].max()
    if max_val - min_val != 0:
        normalized_df[col] = (df_cleaned[col] - min_val) / (max_val - min_val)
    else:
        normalized_df[col] = 0  # Avoid division by zero

print(normalized_df[numerical_cols].head())

# ===============================================================
# Step 4: Save the normalized data
# ===============================================================
normalized_df.to_csv('channel_cost2.csv', index=False)
print("\n\n\nNormalized data saved to 'normalized_dataset.csv'")

# Restore stdout
sys.stdout.log.close()
sys.stdout = sys.stdout.terminal
# Out:
# Basic Statistics of Cleaned Data:
#                Cost   Impressions        Clicks   Conversions        Revenue  \
# count  10000.000000  10000.000000  10000.000000  10000.000000   10000.000000
# mean     901.338977  25520.859200   1308.509700    330.013700   34536.134597
# std      703.119679  14135.944603   1091.880988    367.213746   46604.395223
# min        0.280000   1001.000000     50.000000      5.000000      57.810000
# 25%      297.357500  13267.500000    407.000000     66.000000    5105.355000
# 50%      723.160000  25445.000000    998.000000    191.000000   16212.990000
# 75%     1341.720000  37873.750000   1973.250000    468.000000   44828.012500
# max     2999.860000  49999.000000   4984.000000   2320.000000  419528.920000
#
#         totalmedium
# count  10000.000000
# mean     625.789500
# std      361.360795
# min        1.000000
# 25%      313.000000
# 50%      625.500000
# 75%      938.000000
# max     1286.000000
#
#
#
# Basic Statistics (Cleaned Data):
#
# Column: Cost
# Mean: 901.338977
# Median: 723.16
# Mode: 40.36
#
# Column: Impressions
# Mean: 25520.8592
# Median: 25445.0
# Mode: 48597
#
# Column: Clicks
# Mean: 1308.5097
# Median: 998.0
# Mode: 96
#
# Column: Conversions
# Mean: 330.0137
# Median: 191.0
# Mode: 8
#
# Column: Revenue
# Mean: 34536.134597000004
# Median: 16212.99
# Mode: 596.03
#
# Column: totalmedium
# Mean: 625.7895
# Median: 625.5
# Mode: 1
#
#
#
# Normalized Numerical Features (Cleaned Data):
#        Cost  Impressions    Clicks  Conversions   Revenue  totalmedium
# 0  0.044140     0.147006  0.093839     0.064363  0.065115     0.000000
# 1  0.311050     0.850953  0.212201     0.062203  0.010070     0.000778
# 2  0.036538     0.890138  0.265505     0.204752  0.049024     0.001556
# 3  0.726872     0.852423  0.143291     0.047516  0.051078     0.002335
# 4  0.590196     0.579003  0.183421     0.064795  0.044330     0.003113
#
#
#
# Normalized data saved to 'normalized_dataset.csv'

# %% [markdown]
# ### Statistical_Analysis2

# %%
#BASIC STATISTICS AND NORMALIZATION SCRIPT
import pandas as pd
import numpy as np
import sys

# Redirect output to both console and file for Part 2
class DualOutput:
    def __init__(self, filename):
        self.terminal = sys.stdout
        self.log = open(filename, "w", encoding="utf-8")
    def write(self, message):
        self.terminal.write(message)
        self.log.write(message)
    def flush(self):
        self.terminal.flush()
        self.log.flush()

sys.stdout = DualOutput("conversion2.txt")

# Load cleaned data from Part 1
cleaned_file_path = r"D:\PROJECT\Project2\DataCleaning\conversion.csv"
df_cleaned = pd.read_csv(cleaned_file_path)

# =======================================
# Step 1: Basic Statistics
# =======================================
print("\nBasic Statistics of Cleaned Data:")
print(df_cleaned.describe())
# ===============================================================
# Step 2: Calculate Basic Statistics for Numerical Columns
# Based on cleaned data & display all column values
# ===============================================================
numerical_cols = df_cleaned.select_dtypes(include=[np.number]).columns.tolist()


print("\n\n\nBasic Statistics (Cleaned Data):")
for col in numerical_cols:
    mean_val = np.mean(df_cleaned[col])
    median_val = np.median(df_cleaned[col])
    mode_val = df_cleaned[col].mode()[0] if not df_cleaned[col].mode().empty else np.nan
    
    print(f"\nColumn: {col}")
    print(f"Mean: {mean_val}")
    print(f"Median: {median_val}")
    print(f"Mode: {mode_val}")

# ===============================================================
# Step 3: Normalize Numerical Features using Min-Max Scaling
# Based on cleaned data & display all column values
# ===============================================================
print("\n\n\nNormalized Numerical Features (Cleaned Data):")
normalized_df = df_cleaned.copy()

for col in numerical_cols:
    min_val = df_cleaned[col].min()
    max_val = df_cleaned[col].max()
    if max_val - min_val != 0:
        normalized_df[col] = (df_cleaned[col] - min_val) / (max_val - min_val)
    else:
        normalized_df[col] = 0  # Avoid division by zero

print(normalized_df[numerical_cols].head())

# ===============================================================
# Step 4: Save the normalized data
# ===============================================================
normalized_df.to_csv('conversion2.csv', index=False)
print("\n\n\nNormalized data saved to 'normalized_dataset.csv'")

# Restore stdout
sys.stdout.log.close()
sys.stdout = sys.stdout.terminal
# Out:
# Basic Statistics of Cleaned Data:
#             User_ID  Conversion_Value
# count  10000.000000      10000.000000
# mean    5477.242700        866.970634
# std     2597.944055       1196.613817
# min     1000.000000          0.000000
# 25%     3230.000000          0.000000
# 50%     5446.000000        109.200000
# 75%     7735.250000       1516.532500
# max     9999.000000       4999.490000
#
#
#
# Basic Statistics (Cleaned Data):
#
# Column: User_ID
# Mean: 5477.2427
# Median: 5446.0
# Mode: 2365
#
# Column: Conversion_Value
# Mean: 866.970634
# Median: 109.2
# Mode: 0.0
#
#
#
# Normalized Numerical Features (Cleaned Data):
#     User_ID  Conversion_Value
# 0  0.610290          0.000000
# 1  0.591399          0.484797
# 2  0.180687          0.000000
# 3  0.276031          0.350054
# 4  0.612846          0.000000
#
#
#
# Normalized data saved to 'normalized_dataset.csv'

# %% [markdown]
# ### Statistical_Analysis3

# %%
#BASIC STATISTICS AND NORMALIZATION SCRIPT
import pandas as pd
import numpy as np
import sys

# Redirect output to both console and file for Part 2
class DualOutput:
    def __init__(self, filename):
        self.terminal = sys.stdout
        self.log = open(filename, "w", encoding="utf-8")
    def write(self, message):
        self.terminal.write(message)
        self.log.write(message)
    def flush(self):
        self.terminal.flush()
        self.log.flush()

sys.stdout = DualOutput("customer_lifetime2.txt")

# Load cleaned data from Part 1
cleaned_file_path = r"D:\PROJECT\Project2\DataCleaning\customer_lifetime.csv"
df_cleaned = pd.read_csv(cleaned_file_path)

# =======================================
# Step 1: Basic Statistics
# =======================================
print("\nBasic Statistics of Cleaned Data:")
print(df_cleaned.describe())
# ===============================================================
# Step 2: Calculate Basic Statistics for Numerical Columns
# Based on cleaned data & display all column values
# ===============================================================
numerical_cols = df_cleaned.select_dtypes(include=[np.number]).columns.tolist()


print("\n\n\nBasic Statistics (Cleaned Data):")
for col in numerical_cols:
    mean_val = np.mean(df_cleaned[col])
    median_val = np.median(df_cleaned[col])
    mode_val = df_cleaned[col].mode()[0] if not df_cleaned[col].mode().empty else np.nan
    
    print(f"\nColumn: {col}")
    print(f"Mean: {mean_val}")
    print(f"Median: {median_val}")
    print(f"Mode: {mode_val}")

# ===============================================================
# Step 3: Normalize Numerical Features using Min-Max Scaling
# Based on cleaned data & display all column values
# ===============================================================
print("\n\n\nNormalized Numerical Features (Cleaned Data):")
normalized_df = df_cleaned.copy()

for col in numerical_cols:
    min_val = df_cleaned[col].min()
    max_val = df_cleaned[col].max()
    if max_val - min_val != 0:
        normalized_df[col] = (df_cleaned[col] - min_val) / (max_val - min_val)
    else:
        normalized_df[col] = 0  # Avoid division by zero

print(normalized_df[numerical_cols].head())

# ===============================================================
# Step 4: Save the normalized data
# ===============================================================
normalized_df.to_csv('customer_lifetime2.csv', index=False)
print("\n\n\nNormalized data saved to 'normalized_dataset.csv'")

# Restore stdout
sys.stdout.log.close()
sys.stdout = sys.stdout.terminal
# Out:
# Basic Statistics of Cleaned Data:
#        Total_Purchases  Customer_Lifetime_Value  Subscription_Length_Months  \
# count     10000.000000             10000.000000                10000.000000
# mean          5.494800              1432.987634                    6.513100
# std           2.884997               817.199900                    3.436773
# min           1.000000                20.100000                    1.000000
# 25%           3.000000               740.677500                    4.000000
# 50%           5.000000              1396.765000                    7.000000
# 75%           8.000000              2068.640000                    9.000000
# max          10.000000              4067.700000                   12.000000
#
#           totalplan
# count  10000.000000
# mean     715.648200
# std      413.924597
# min        1.000000
# 25%      358.000000
# 50%      715.000000
# 75%     1072.000000
# max     1522.000000
#
#
#
# Basic Statistics (Cleaned Data):
#
# Column: Total_Purchases
# Mean: 5.4948
# Median: 5.0
# Mode: 3
#
# Column: Customer_Lifetime_Value
# Mean: 1432.987634
# Median: 1396.7649999999999
# Mode: 47.36
#
# Column: Subscription_Length_Months
# Mean: 6.5131
# Median: 7.0
# Mode: 2
#
# Column: totalplan
# Mean: 715.6482
# Median: 715.0
# Mode: 1
#
#
#
# Normalized Numerical Features (Cleaned Data):
#    Total_Purchases  Customer_Lifetime_Value  Subscription_Length_Months  \
# 0         0.666667                 0.406933                    0.545455
# 1         0.222222                 0.177144                    0.000000
# 2         0.222222                 0.213257                    0.454545
# 3         0.222222                 0.291163                    0.272727
# 4         0.888889                 0.664772                    0.181818
#
#    totalplan
# 0   0.000000
# 1   0.000657
# 2   0.001315
# 3   0.001972
# 4   0.002630
#
#
#
# Normalized data saved to 'normalized_dataset.csv'

# %% [markdown]
# ### Statistical_Analysis4

# %%
#BASIC STATISTICS AND NORMALIZATION SCRIPT
import pandas as pd
import numpy as np
import sys

# Redirect output to both console and file for Part 2
class DualOutput:
    def __init__(self, filename):
        self.terminal = sys.stdout
        self.log = open(filename, "w", encoding="utf-8")
    def write(self, message):
        self.terminal.write(message)
        self.log.write(message)
    def flush(self):
        self.terminal.flush()
        self.log.flush()

sys.stdout = DualOutput("tamilnadu_Customer2.txt")

# Load cleaned data from Part 1
cleaned_file_path = r"D:\PROJECT\Project2\DataCleaning\tamilnadu_Customer.csv"
df_cleaned = pd.read_csv(cleaned_file_path)

# =======================================
# Step 1: Basic Statistics
# =======================================
print("\nBasic Statistics of Cleaned Data:")
print(df_cleaned.describe())
# ===============================================================
# Step 2: Calculate Basic Statistics for Numerical Columns
# Based on cleaned data & display all column values
# ===============================================================
numerical_cols = df_cleaned.select_dtypes(include=[np.number]).columns.tolist()


print("\n\n\nBasic Statistics (Cleaned Data):")
for col in numerical_cols:
    mean_val = np.mean(df_cleaned[col])
    median_val = np.median(df_cleaned[col])
    mode_val = df_cleaned[col].mode()[0] if not df_cleaned[col].mode().empty else np.nan
    
    print(f"\nColumn: {col}")
    print(f"Mean: {mean_val}")
    print(f"Median: {median_val}")
    print(f"Mode: {mode_val}")

# ===============================================================
# Step 3: Normalize Numerical Features using Min-Max Scaling
# Based on cleaned data & display all column values
# ===============================================================
print("\n\n\nNormalized Numerical Features (Cleaned Data):")
normalized_df = df_cleaned.copy()

for col in numerical_cols:
    min_val = df_cleaned[col].min()
    max_val = df_cleaned[col].max()
    if max_val - min_val != 0:
        normalized_df[col] = (df_cleaned[col] - min_val) / (max_val - min_val)
    else:
        normalized_df[col] = 0  # Avoid division by zero

print(normalized_df[numerical_cols].head())

# ===============================================================
# Step 4: Save the normalized data
# ===============================================================
normalized_df.to_csv('tamilnadu_Customer2.csv', index=False)
print("\n\n\nNormalized data saved to 'normalized_dataset.csv'")

# Restore stdout
sys.stdout.log.close()
sys.stdout = sys.stdout.terminal
# Out:
# Basic Statistics of Cleaned Data:
#                 Age
# count  10000.000000
# mean      39.284000
# std       12.389677
# min       18.000000
# 25%       28.000000
# 50%       40.000000
# 75%       50.000000
# max       60.000000
#
#
#
# Basic Statistics (Cleaned Data):
#
# Column: Age
# Mean: 39.284
# Median: 40.0
# Mode: 41
#
#
#
# Normalized Numerical Features (Cleaned Data):
#         Age
# 0  0.119048
# 1  0.404762
# 2  0.285714
# 3  0.071429
# 4  0.404762
#
#
#
# Normalized data saved to 'normalized_dataset.csv'

# %% [markdown]
# ### Statistical_Analysis5

# %%
#BASIC STATISTICS AND NORMALIZATION SCRIPT
import pandas as pd
import numpy as np
import sys

# Redirect output to both console and file for Part 2
class DualOutput:
    def __init__(self, filename):
        self.terminal = sys.stdout
        self.log = open(filename, "w", encoding="utf-8")
    def write(self, message):
        self.terminal.write(message)
        self.log.write(message)
    def flush(self):
        self.terminal.flush()
        self.log.flush()

sys.stdout = DualOutput("touchpoint2.txt")

# Load cleaned data from Part 1
cleaned_file_path = r"D:\PROJECT\Project2\DataCleaning\touchpoint.csv"
df_cleaned = pd.read_csv(cleaned_file_path)

# =======================================
# Step 1: Basic Statistics
# =======================================
print("\nBasic Statistics of Cleaned Data:")
print(df_cleaned.describe())
# ===============================================================
# Step 2: Calculate Basic Statistics for Numerical Columns
# Based on cleaned data & display all column values
# ===============================================================
numerical_cols = df_cleaned.select_dtypes(include=[np.number]).columns.tolist()


print("\n\n\nBasic Statistics (Cleaned Data):")
for col in numerical_cols:
    mean_val = np.mean(df_cleaned[col])
    median_val = np.median(df_cleaned[col])
    mode_val = df_cleaned[col].mode()[0] if not df_cleaned[col].mode().empty else np.nan
    
    print(f"\nColumn: {col}")
    print(f"Mean: {mean_val}")
    print(f"Median: {median_val}")
    print(f"Mode: {mode_val}")

# ===============================================================
# Step 3: Normalize Numerical Features using Min-Max Scaling
# Based on cleaned data & display all column values
# ===============================================================
print("\n\n\nNormalized Numerical Features (Cleaned Data):")
normalized_df = df_cleaned.copy()

for col in numerical_cols:
    min_val = df_cleaned[col].min()
    max_val = df_cleaned[col].max()
    if max_val - min_val != 0:
        normalized_df[col] = (df_cleaned[col] - min_val) / (max_val - min_val)
    else:
        normalized_df[col] = 0  # Avoid division by zero

print(normalized_df[numerical_cols].head())

# ===============================================================
# Step 4: Save the normalized data
# ===============================================================
normalized_df.to_csv('touchpoint2.csv', index=False)
print("\n\n\nNormalized data saved to 'normalized_dataset.csv'")

# Restore stdout
sys.stdout.log.close()
sys.stdout = sys.stdout.terminal
# Out:
# Basic Statistics of Cleaned Data:
#             User_ID     totaltype   totalmedium     totalpage  totalchannel
# count  10000.000000  10000.000000  10000.000000  10000.000000  10000.000000
# mean    5524.600400     12.100500     12.100500     12.100500     12.100500
# std     2610.142178      7.194858      7.194858      7.194858      7.194858
# min     1000.000000      1.000000      1.000000      1.000000      1.000000
# 25%     3293.000000      6.000000      6.000000      6.000000      6.000000
# 50%     5492.500000     12.000000     12.000000     12.000000     12.000000
# 75%     7832.250000     17.000000     17.000000     17.000000     17.000000
# max     9997.000000     36.000000     36.000000     36.000000     36.000000
#
#
#
# Basic Statistics (Cleaned Data):
#
# Column: User_ID
# Mean: 5524.6004
# Median: 5492.5
# Mode: 1282
#
# Column: totaltype
# Mean: 12.1005
# Median: 12.0
# Mode: 1
#
# Column: totalmedium
# Mean: 12.1005
# Median: 12.0
# Mode: 1
#
# Column: totalpage
# Mean: 12.1005
# Median: 12.0
# Mode: 1
#
# Column: totalchannel
# Mean: 12.1005
# Median: 12.0
# Mode: 1
#
#
#
# Normalized Numerical Features (Cleaned Data):
#     User_ID  totaltype  totalmedium  totalpage  totalchannel
# 0  0.007002   0.000000     0.000000   0.000000      0.000000
# 1  0.981327   0.028571     0.028571   0.028571      0.028571
# 2  0.153718   0.057143     0.057143   0.057143      0.057143
# 3  0.536734   0.085714     0.085714   0.085714      0.085714
# 4  0.678448   0.114286     0.114286   0.114286      0.114286
#
#
#
# Normalized data saved to 'normalized_dataset.csv'
